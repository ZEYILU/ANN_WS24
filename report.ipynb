# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import os
import random
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, Dataset
from utils import get_data_loaders
# from train import train_model
# from evaluate import evaluate_model
# from model import CNNModel

# %%
from utils import count_samples, visualize_samples

# 设定数据路径
train_dir = "D:/thws Mai/ann/TRAIN"
test_dir = "D:/thws Mai/ann/TEST"
test2_dir = "D:/thws Mai/ann/TEST2"

# 统计样本数
print("数据集类别及样本数统计：")
for dataset_name, dataset_dir in zip(["TRAIN", "TEST", "TEST2"], [train_dir, test_dir, test2_dir]):
    sample_counts = count_samples(dataset_dir)
    print(f"\n {dataset_name} 数据集:")
    for category, count in sample_counts.items():
        print(f"  - {category}: {count} samples")

# 可视化部分样本
print("\n可视化 TRAIN 数据集样本：")
visualize_samples(train_dir, num_images=5)
# Out:
# 数据集类别及样本数统计：
#
#  TRAIN 数据集:
#   - 1: 6000 samples
#   - 2: 6000 samples
#   - 3: 6000 samples
#   - 4: 6000 samples
#   - 5: 6000 samples
#   - 6: 6000 samples
#
#  TEST 数据集:
#   - 1: 1000 samples
#   - 2: 1000 samples
#   - 3: 1000 samples
#   - 4: 1000 samples
#   - 5: 1000 samples
#   - 6: 1000 samples
#
#  TEST2 数据集:
#   - 1: 1000 samples
#   - 2: 1000 samples
#   - 3: 1000 samples
#   - 4: 1000 samples
#   - 5: 1000 samples
#   - 6: 1000 samples
#
# 可视化 TRAIN 数据集样本：

# %%
from utils import dataset_stats
from data_loader import get_data_loaders

train_loader, test_loader, test2_loader = get_data_loaders(batch_size=32, preprocess_test=False)


# 计算数据集统计信息
print("\n📊 计算数据集统计信息：")
train_stats = dataset_stats(train_loader.dataset)
test_stats = dataset_stats(test_loader.dataset)
test2_stats = dataset_stats(test2_loader.dataset) if test2_loader else None

print("Train dataset stats:", train_stats)
print("Test dataset stats:", test_stats)
if test2_stats:
    print("Test2 dataset stats:", test2_stats)
# Out:
# 📊 计算数据集统计信息：
# Train dataset stats: {'min': 0.0, 'max': 1.0, 'mean': 0.18724751472473145, 'std': 0.34632912278175354}
# Test dataset stats: {'min': 0.0, 'max': 1.0, 'mean': 0.496489942073822, 'std': 0.4653092622756958}
# Test2 dataset stats: {'min': 0.0, 'max': 1.0, 'mean': 0.8146815299987793, 'std': 0.3396167755126953}

# %%
from train import train_model

# 训练任务 1
model, train_losses, train_accs = train_model(task="task1", batch_size=, num_epochs=20)
# Out:
# Epoch 1/20 - Train Loss: 0.4549, Train Acc: 0.8524
# Epoch 2/20 - Train Loss: 0.2753, Train Acc: 0.9161
# Epoch 3/20 - Train Loss: 0.2190, Train Acc: 0.9326
# Epoch 4/20 - Train Loss: 0.1903, Train Acc: 0.9406
# Epoch 5/20 - Train Loss: 0.1730, Train Acc: 0.9471
# Epoch 6/20 - Train Loss: 0.1599, Train Acc: 0.9512
# Epoch 7/20 - Train Loss: 0.1501, Train Acc: 0.9540
# Epoch 8/20 - Train Loss: 0.1407, Train Acc: 0.9573

# %%
# -----------------------------
# 绘制训练曲线：训练损失和训练准确率
# -----------------------------
num_epochs = 20
epochs = list(range(1, num_epochs+1))
plt.figure(figsize=(12, 5))
# 绘制 Loss 曲线
plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label='Train Loss', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss per Epoch')
plt.legend()
plt.grid(True)

# 绘制 Accuracy 曲线
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accs, label='Train Accuracy', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training Accuracy per Epoch')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
from evaluate import evaluate_model

# 评估任务 1
test_loss, test_acc = evaluate_model(task="task1", batch_size=32)

# %%
from train import train_model

# 训练任务 1
model, train_losses, train_accs = train_model(task="task1", batch_size=64, num_epochs=20)

# %%
# -----------------------------
# 绘制训练曲线：训练损失和训练准确率
# -----------------------------
num_epochs = 20
epochs = list(range(1, num_epochs+1))
plt.figure(figsize=(12, 5))
# 绘制 Loss 曲线
plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label='Train Loss', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss per Epoch')
plt.legend()
plt.grid(True)

# 绘制 Accuracy 曲线
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accs, label='Train Accuracy', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training Accuracy per Epoch')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
from evaluate import evaluate_model

# 评估任务 1
test_loss, test_acc = evaluate_model(task="task1", batch_size=32)

# %%
from train_task2 import train_task2

# 训练任务二
model, train_losses, train_accs = train_task2(batch_size=64, num_epochs=20)

# %%
from evaluate_task2 import evaluate_model_task2

# 评估任务二
test_loss, test_acc, test2_loss, test2_acc = evaluate_model_task2(batch_size=64)
